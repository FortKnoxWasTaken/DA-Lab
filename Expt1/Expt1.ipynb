# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
nasa_data = pd.read_csv('crimedata_csv_Hastings-Sunrise_AllYears.csv')

# %%
nasa_data.head()
# Out:
#                          TYPE  YEAR  MONTH  DAY  HOUR  MINUTE  \
# 0  Break and Enter Commercial  2018      5   16    17       0
# 1  Break and Enter Commercial  2018      2   27    21      40
# 2  Break and Enter Commercial  2012      9   25    22      33
# 3  Break and Enter Commercial  2006      5   12    20       0
# 4  Break and Enter Commercial  2006      5   13    20      58
#
#       HUNDRED_BLOCK     NEIGHBOURHOOD            X             Y
# 0  10XX BOUNDARY RD  Hastings-Sunrise  498275.6200  5.458125e+06
# 1  11XX ROSSLAND ST  Hastings-Sunrise  496691.9762  5.458066e+06
# 2  13XX BOUNDARY RD  Hastings-Sunrise  498274.1930  5.457717e+06
# 3  13XX BOUNDARY RD  Hastings-Sunrise  498274.2719  5.457739e+06
# 4  13XX BOUNDARY RD  Hastings-Sunrise  498274.2719  5.457739e+06

# %%
# nasa_data = nasa_data[]

# %%
nasa_data.shape
# Out:
# (29176, 10)

# %%
nasa_data.isnull().sum()
# Out:
# TYPE             0
# YEAR             0
# MONTH            0
# DAY              0
# HOUR             0
# MINUTE           0
# HUNDRED_BLOCK    0
# NEIGHBOURHOOD    0
# X                0
# Y                0
# dtype: int64

# %%
sns.set()
sns.set_style('whitegrid')

# %%
sns.pairplot(nasa_data)
